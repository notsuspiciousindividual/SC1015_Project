# %% [markdown]
# # Extracting Data from TheMovieDB for all nominated and winners at the Academy Awards (Oscars)

# %%
import numpy as np
import pandas as pd

# For API usage
import requests as r

#our lifesaver, the progress bar
from tqdm import tqdm

# %%
#API Key 
API_KEY = 'b4c353d61e8791dac39e77e69a2c08d3' 

##This is to extract our the whole database from their daily dump
simple_extract = pd.read_json('datasets/movie_ids_03_25_2023.json', lines=True)
nominated = pd.read_csv('DataSet Work/the_oscar_award.csv')
print(simple_extract.dtypes)
print(simple_extract.head(5))
print(nominated.dtypes)
print(nominated.head(5))
# Out:
# adult                bool
# id                  int64
# original_title     object
# popularity        float64
# video                bool
# dtype: object
#    adult     id                      original_title  popularity  video
# 0  False   3924                             Blondie       3.502  False
# 1  False   6124                 Der Mann ohne Namen       0.600  False
# 2  False   8773                 L'Amour à vingt ans       2.722  False
# 3  False  25449  New World Disorder 9: Never Enough       1.097  False
# 4  False  31975      Sesame Street: Elmo Loves You!       0.600   True
# year_film         int64
# year_ceremony     int64
# ceremony          int64
# category         object
# name             object
# film             object
# winner             bool
# dtype: object
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False

# %%
nominated = nominated[['year_film','category','film','winner']]
print(nominated.head(5))
# Out:
#    year_film category              film  winner
# 0       1927    ACTOR         The Noose   False
# 1       1927    ACTOR  The Last Command    True
# 2       1927  ACTRESS   A Ship Comes In   False
# 3       1927  ACTRESS        7th Heaven    True
# 4       1927  ACTRESS    Sadie Thompson   False

# %%
nominated_clean = nominated.dropna().reset_index(drop=True)

# %%
nominated_clean_noCat = nominated_clean.drop(columns=['category'])

# %%
nominated_clean_noCat = nominated_clean_noCat.drop_duplicates().reset_index(drop=True)
nominated_clean_noCat
# Out:
#       year_film                               film  winner
# 0          1927                          The Noose   False
# 1          1927                   The Last Command    True
# 2          1927                    A Ship Comes In   False
# 3          1927                         7th Heaven    True
# 4          1927                     Sadie Thompson   False
# ...         ...                                ...     ...
# 5852       2022                  Top Gun: Maverick    True
# 5853       2022           Avatar: The Way of Water    True
# 5854       2022  Glass Onion: A Knives Out Mystery   False
# 5855       2022                      Women Talking    True
# 5856       2022                Welcome to Chechnya    True
#
# [5857 rows x 3 columns]

# %% [markdown]
# ### Some films may have won only some but there will be a repeat entry of false if they did not win every award possible, making for loop to remove these duplicates as well.

# %%
# If there are duplicates films with both True and false entry, we drop the false entry as the film did at least win an oscar
# To do this, groupby first to sort by TRUE To make sure the true version is kept
nominated_clean_noCat = nominated_clean_noCat.sort_values(by=['winner'], ascending=False)

nominated_clean_noCat = nominated_clean_noCat.drop_duplicates(subset=['film','year_film'], keep='first')
# Now that there are no more duplicates, we can resort by original index and then reset the index
nominated_clean_noCat = nominated_clean_noCat.sort_index().reset_index(drop=True)

# %%
nominated_clean_noCat
# Out:
#       year_film                               film  winner
# 0          1927                          The Noose   False
# 1          1927                   The Last Command    True
# 2          1927                    A Ship Comes In   False
# 3          1927                         7th Heaven    True
# 4          1927                     Sadie Thompson   False
# ...         ...                                ...     ...
# 5093       2022                  Top Gun: Maverick    True
# 5094       2022           Avatar: The Way of Water    True
# 5095       2022  Glass Onion: A Knives Out Mystery   False
# 5096       2022                      Women Talking    True
# 5097       2022                Welcome to Chechnya    True
#
# [5098 rows x 3 columns]

# %%
# Duplicating the dataframe for later use
original_nominated_cleaned = nominated_clean_noCat.copy()
# Out:
#       year_film                               film  winner
# 0          1927                          The Noose   False
# 1          1927                   The Last Command    True
# 2          1927                    A Ship Comes In   False
# 3          1927                         7th Heaven    True
# 4          1927                     Sadie Thompson   False
# ...         ...                                ...     ...
# 5093       2022                  Top Gun: Maverick    True
# 5094       2022           Avatar: The Way of Water    True
# 5095       2022  Glass Onion: A Knives Out Mystery   False
# 5096       2022                      Women Talking    True
# 5097       2022                Welcome to Chechnya    True
#
# [5098 rows x 3 columns]

# %% [markdown]
# # Downloading info from TheMovieDB for movies that had been nominated or won

# %%
# Downloading the data from the API directly from nominated_clean_noCat films

# This is the function that will be used to extract the data from the API
https://api.themoviedb.org/3/search/movie?api_key=<<api_key>>&language=en-US&page=1&include_adult=false

# %%
# convert both set of titles to all uppercase and remove non-alphanumeric characters

nominated_clean_noCat['film'] = nominated_clean_noCat['film'].str.upper().str.replace(r'[^A-Z0-9]', '')
simple_extract['original_title'] = simple_extract['original_title'].str.upper().str.replace(r'[^A-Z0-9]', '')
# Out:
# /var/folders/pv/4s9_lh1909z14tnpgcdzkk3m0000gn/T/ipykernel_2354/439819186.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   nominated_clean_noCat['film'] = nominated_clean_noCat['film'].str.upper().str.replace(r'[^A-Z0-9]', '')
# /var/folders/pv/4s9_lh1909z14tnpgcdzkk3m0000gn/T/ipykernel_2354/439819186.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   simple_extract['original_title'] = simple_extract['original_title'].str.upper().str.replace(r'[^A-Z0-9]', '')

# %%
simple_extract = simple_extract.dropna().drop_duplicates(subset=['original_title'], keep='first')
simple_extract
# Out:
#         adult       id                              original_title  \
# 0       False     3924                                     BLONDIE
# 1       False     6124                            DERMANNOHNENAMEN
# 2       False     8773                              LAMOURVINGTANS
# 3       False    25449                NEWWORLDDISORDER9NEVERENOUGH
# 4       False    31975                    SESAMESTREETELMOLOVESYOU
# ...       ...      ...                                         ...
# 791501  False  1104366                                 PETSSEASON1
# 791503  False  1104369                      MIYUKIWATANABEMIRUNEKO
# 791504  False  1104370                                     CAFFRIO
# 791506  False  1104372                                 REDMEATHAND
# 791507  False  1104374  TIKTOKCEOSHOUZICHEWTESTIFIESBEFORECONGRESS
#
#         popularity  video
# 0            3.502  False
# 1            0.600  False
# 2            2.722  False
# 3            1.097  False
# 4            0.600   True
# ...            ...    ...
# 791501       0.000  False
# 791503       0.000  False
# 791504       0.000  False
# 791506       0.000  False
# 791507       0.000  False
#
# [600096 rows x 5 columns]

# %%
# Downloading from TheMovieDB with API
# We will get the movie id from the simple_extract dataframe and then use that to get the movie details
# We will then use the movie id to extract movie details from TheMovieDB
movie_ids = []
notFoundMovies = []

for i in tqdm(range(len(nominated_clean_noCat))):
    # Get the movie id from the simple_extract dataframe
    movie_id = simple_extract[simple_extract['original_title'] == nominated_clean_noCat['film'][i]]['id']

    if not movie_id.empty:  # Check if the movie_id is found in simple_extract dataframe
        movie_ids.append(int(movie_id))  # Convert to integer and append to the list
    else:
        notFoundMovies.append(nominated_clean_noCat['film'][i])

print(len(notFoundMovies))
notFoundMovies
# Get the movie details from TheMovieDB
#movie_details = r.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, API_KEY)).json()
# Out:
# 100%|██████████| 5098/5098 [02:22<00:00, 35.84it/s]
# 521
# ['CHANG',
#  'FOURDEVILS',
#  'HOLLYWOODREVUE',
#  'SONGOFTHEFLAME',
#  'BIGBROADCASTOF1936',
#  'WINGSOVERMTEVEREST',
#  'BRIDEOFFRANKENSTEIN',
#  'TRAILOFTHELONESOMEPINE',
#  'OLDMILLPOND',
#  'WALTERWANGERSVOGUESOF1938',
#  'ONEHUNDREDMENANDAGIRL',
#  'GRANDILLUSION',
#  'THEDARKCOMMAND',
#  'THEDEVILPAYSOFF',
#  'MRGARDENIAJONES',
#  'MOSCOWSTRIKESBACK',
#  'PRELUDETOWAR',
#  'UNITEDSTATESMARINEBAND',
#  'THEBATTLEOFRUSSIA',
#  'SILENTVILLAGE',
#  'BISMARCKCONVOYSMASHED',
#  'THE500HATSOFBARTHOLOMEWCUBBINS',
#  'YANKEEDOODLEMOUSE',
#  'CAVALCADEOFDANCEWITHVELOZANDYOLANDA',
#  'HOLLYWOODINUNIFORM',
#  'ARTUROTOSCANINI',
#  'WOMANOFTHETOWN',
#  'ANDTOTHINKISAWITONMULBERRYSTREET',
#  'THESULLIVANS',
#  'GIJOE',
#  'MIGHTYMOUSEINGYPSYLIFE',
#  'THEPOETANDPEASANT',
#  'SCREENSNAPSHOTS25THANNIVERSARY',
#  'THREEISAFAMILY',
#  'PARAMOUNTNEWSISSUE37TWENTIETHANNIVERSARYISSUE19271947',
#  'CHOPINSMUSICALMOMENTS',
#  'VACATIONFROMMARRIAGE',
#  'CHILDRENOFPARADISE',
#  'OPENCITY',
#  'AVOICEISBORNTHESTORYOFNIKLOSGAFNI',
#  'ACAGEOFNIGHTINGALES',
#  'SYMPHONYOFACITY',
#  'THEADVENTURESOFDONJUAN',
#  'THEBICYCLETHIEF',
#  'PAISAN',
#  'SUNSETBLVD',
#  'INBEAVERVALLEY',
#  'BITTERRICE',
#  'HOUSEONTELEGRAPHHILL',
#  'TALESOFHOFFMANN',
#  'THEBIGCARNIVAL',
#  'RASHOMON',
#  'THEGARDENSPIDEREPEIRADIADEMA',
#  'MIRACLEOFFATIMA',
#  'ROMANCEOFTRANSPORTATION',
#  'THEMERRYWIVESOFWINDSOROVERTURE',
#  'RETURNTOGLENNASCAUL',
#  'ADVENTURESOFROBINSONCRUSOE',
#  'THEEARRINGSOFMADAMEDE',
#  'GATEOFHELL',
#  'THESTRAUSSFANTASY',
#  'BREADLOVEANDDREAMS',
#  'UGETSU',
#  'HELENKELLERINHERSTORY',
#  'THESHEEPHASFIVELEGS',
#  'MRHULOTSHOLIDAY',
#  'THESILENTWORLD',
#  'WHEREMOUNTAINSFLOAT',
#  'THECAPTAINOFKOPENICK',
#  'HARPOFBURMA',
#  'QIVITOQ',
#  'THEPROUDANDTHEBEAUTIFUL',
#  'THEDEVILCAMEATNIGHT',
#  'GATESOFPARIS',
#  'THENIGHTSOFCABIRIA',
#  'VITELLONI',
#  'THEROADAYEARLONG',
#  'THEUSUALUNIDENTIFIEDTHIEVES',
#  'SERENGETISHALLNOTDIE',
#  'BLACKORPHEUS',
#  'THEVILLAGEONTHERIVER',
#  'THERUNNINGJUMPINGANDSTANDINGSTILLFILM',
#  'THE400BLOWS',
#  'WILDSTRAWBERRIES',
#  'ACITYCALLEDCOPENHAGEN',
#  'KAPO',
#  'THENINTHCIRCLE',
#  'THEVIRGINSPRING',
#  'SONGWITHOUTENDTHESTORYOFFRANZLISZT',
#  'NEVERONSUNDAY',
#  'YOJIMBO',
#  'LAGRANDEOLIMPIADEOLYMPICGAMES1960',
#  'LECIELETLABOUESKYABOVEANDMUDBENEATH',
#  'LUOMOINGRIGIOTHEMANINGRAY',
#  'HARRYANDTHEBUTLER',
#  'IMMORTALLOVE',
#  'THEIMPORTANTMAN',
#  'PLACIDO',
#  'THROUGHAGLASSDARKLY',
#  'ERSATZTHESUBSTITUTE',
#  'BALLONVOLEPLAYBALL',
#  'BALLADOFASOLDIER',
#  'GENERALDELLAROVERE',
#  'ALVORADABRAZILSCHANGINGFACE',
#  'DYLANTHOMAS',
#  'THEFOURDAYSOFNAPLES',
#  'KEEPEROFPROMISESTHEGIVENWORD',
#  'SUNDAYSANDCYBELE',
#  'FREUD',
#  'MEREDITHWILLSONSTHEMUSICMAN',
#  'SYMPOSIUMONPOPULARSONGS',
#  'THECLIFFDWELLERSFORMERLYTITLEDONEPLUSONE',
#  'HEUREUXANNIVERSAIREHAPPYANNIVERSARY',
#  'DIVORCEITALIANSTYLE',
#  'LASTYEARATMARIENBAD',
#  'THROUGHAGLASSDARKLY',
#  'FEDERICOFELLINIS812',
#  'THELEOPARD',
#  'LEMAILLONETLACHAINETHELINKANDTHECHAIN',
#  'KNIFEINTHEWATER',
#  'THEREDLANTERNS',
#  'TWINSISTERSOFKYOTO',
#  'SUNDAYSANDCYBELE',
#  'THEGAMEIGRA',
#  'HOMEMADECAR',
#  'SIXSIDEDTRIANGLE',
#  'THEFOURDAYSOFNAPLES',
#  'MARRIAGEITALIANSTYLE',
#  'ZORBATHEGREEK',
#  'THEHUMANDUTCH',
#  'JACQUESYVESCOUSTEAUSWORLDWITHOUTSUN',
#  'OVERTHERE191418',
#  'KENOJUAK',
#  'RAVENSEND',
#  'SALLAH',
#  'THEUMBRELLASOFCHERBOURG',
#  'WOMANINTHEDUNES',
#  'NUDNIK2',
#  'THATMANFROMRIO',
#  'WOMANINTHEDUNES',
#  'TODIEINMADRID',
#  'BLOODONTHELAND',
#  'MARRIAGEITALIANSTYLE',
#  'THESHOPONMAINSTREET',
#  'THEUMBRELLASOFCHERBOURG',
#  'THEDOTANDTHELINE',
#  'THETHIEVINGMAGPIELAGAZZALADRA',
#  'THECHICKENLEPOULET',
#  'FORTRESSOFPEACE',
#  'THOSEMAGNIFICENTMENINTHEIRFLYINGMACHINES',
#  'THESHOPONMAINSTREET',
#  'THEGOSPELACCORDINGTOSTMATTHEW',
#  'ISPARISBURNING',
#  'JULIETOFTHESPIRITS',
#  'LEVOLCANINTERDITTHEFORBIDDENVOLCANO',
#  'AYEARTOWARDTOMORROW',
#  'THEBATTLEOFALGIERS',
#  'LOVESOFABLONDE',
#  'THEBIBLE',
#  'HERBALPERTANDTHETIJUANABRASSDOUBLEFEATURE',
#  'THEANDERSONPLATOON',
#  'CLOSELYWATCHEDTRAINS',
#  'IEVENMETHAPPYGYPSIES',
#  'LIVEFORLIFE',
#  'PORTRAITOFCHIEKO',
#  'HYPOTHESEBETA',
#  'THEBATTLEOFALGIERS',
#  'THELEGENDARYCHAMPIONS',
#  'THEBOYSOFPAULSTREET',
#  'THEFIREMENSBALL',
#  'THEGIRLWITHTHEPISTOL',
#  'THEYOUNGGIRLSOFROCHEFORT',
#  'ARTHURRUBINSTEINTHELOVEOFLIFE',
#  'THEOLYMPICSINMEXICO',
#  'THEBATTLEOFNERETVA',
#  'MYNIGHTATMAUDS',
#  'CHARIOTSOFTHEGODS',
#  'OISIN',
#  'INVESTIGATIONOFACITIZENABOVESUSPICION',
#  'THEFURTHERADVENTURESOFUNCLESAMPARTTWO',
#  'MYNIGHTATMAUDS',
#  'THERAEXPEDITIONS',
#  'THESORROWANDTHEPITY',
#  'ADVENTURESINPERCEPTION',
#  'DODESKADEN',
#  'THEEMIGRANTS',
#  'THEGARDENOFTHEFINZICONTINIS',
#  'THEPOLICEMAN',
#  'TCHAIKOVSKY',
#  'WILLYWONKAANDTHECHOCOLATEFACTORY',
#  'THECONFORMIST',
#  'INVESTIGATIONOFACITIZENABOVESUSPICION',
#  'THEEMIGRANTS',
#  'APEANDSUPERAPE',
#  'THESILENTREVOLUTION',
#  'HUNDERTWASSERSRAINYDAY',
#  'THISTINYWORLD',
#  'THEDAWNSHEREAREQUIET',
#  'THEDISCREETCHARMOFTHEBOURGEOISIE',
#  'ILOVEYOUROSA',
#  'MYDEARESTSEORITA',
#  'THENEWLAND',
#  'MURMUROFTHEHEART',
#  'BROTHERSUNSISTERMOON',
#  'BATTLEOFBERLIN',
#  'CHILDRENATWORKPAISTIAGOBAIR',
#  'THEHOUSEONCHELOUCHESTREET',
#  'THEPEDESTRIAN',
#  'THE81STBLOW',
#  'CATSPLAY',
#  'THETRUCE',
#  'ONEEYEDMENAREKINGS',
#  'THESTORYOFADELEH',
#  'DERSUUZALA',
#  'LETTERSFROMMARUSIA',
#  'SANDAKANNO8',
#  'ANDNOWMYLOVE',
#  'SEVENBEAUTIES',
#  'FELLINISCASANOVA',
#  'BLACKANDWHITEINCOLOR',
#  'JACOBTHELIAR',
#  'ASPECIALDAY',
#  'OFTIMETOMBSANDTREASURE',
#  'IPHIGENIA',
#  'MADAMEROSA',
#  'OPERATIONTHUNDERBOLT',
#  'THATOBSCUREOBJECTOFDESIRE',
#  'MOHAMMADMESSENGEROFGOD',
#  'THESLIPPERANDTHEROSETHESTORYOFCINDERELLA',
#  'THEDOONESBURYSPECIAL',
#  'AUTUMNSONATA',
#  'THELOVERSWIND',
#  'GETOUTYOURHANDKERCHIEFS',
#  'THEGLASSCELL',
#  'HUNGARIANS',
#  'WHITEBIMBLACKEAR',
#  'DAE',
#  'THEMAIDSOFWILKO',
#  'MAMATURNSAHUNDRED',
#  'ASIMPLESTORY',
#  'THETINDRUM',
#  'TOFORGETVENICE',
#  'DREAMDOLL',
#  'KAGEMUSHATHESHADOWWARRIOR',
#  'THEYELLOWSTARTHEPERSECUTIONOFTHEJEWSINEUROPE193345',
#  'THELASTMETRO',
#  'MOSCOWDOESNOTBELIEVEINTEARS',
#  'ALLNOTHING',
#  'MONONCLEDAMERIQUE',
#  'THEBOATISFULL',
#  'MUDDYRIVER',
#  'ALSINOANDTHECONDOR',
#  'COUPDETORCHONCLEANSLATE',
#  'THEFLIGHTOFTHEEAGLE',
#  'VOLVERAEMPEZARTOBEGINAGAIN',
#  'QUESTFORFIRE',
#  'FANNYALEXANDER',
#  'THERETURNOFMARTINGUERRE',
#  'YOUAREFREEIHRZENTFREI',
#  'JOBSREVOLT',
#  'SUNDAEINNEWYORK',
#  'RECOLLECTIONSOFPAVLOVSK',
#  'DANGEROUSMOVES',
#  'WARTIMEROMANCE',
#  'LASMADRESTHEMOTHERSOFPLAZADEMAYO',
#  'ANGRYHARVEST',
#  'COLONELREDL',
#  'THEOFFICIALSTORY',
#  'THREEMENANDACRADLE',
#  'WHENFATHERWASAWAYONBUSINESS',
#  'THEDECLINEOFTHEAMERICANEMPIRE',
#  'MYSWEETLITTLEVILLAGE',
#  'AGREEKTRAGEDY',
#  'MYLIFEASADOG',
#  'EYESONTHEPRIZEAMERICASCIVILRIGHTSYEARSBRIDGETOFREEDOM1965',
#  'THETENYEARLUNCHTHEWITANDLEGENDOFTHEALGONQUINROUNDTABLE',
#  'AUREVOIRLESENFANTSGOODBYECHILDREN',
#  'COURSECOMPLETED',
#  'THEMANWHOPLANTEDTREES',
#  'ACRYINTHEDARK',
#  'THECRYOFREASONBEYERSNAUDANAFRIKANERSPEAKSOUT',
#  'HOTELTERMINUSTHELIFEANDTIMESOFKLAUSBARBIE',
#  'FAMILYGATHERING',
#  'PELLETHECONQUEROR',
#  'WOMENONTHEVERGEOFANERVOUSBREAKDOWN',
#  'MYLEFTFOOT',
#  'CINEMAPARADISO',
#  'JESUSOFMONTREAL',
#  'WALTZINGREGITZE',
#  'WHATHAPPENEDTOSANTIAGO',
#  'DAYSOFWAITING',
#  'JOURNEYOFHOPE',
#  'JUDOU',
#  'THENASTYGIRL',
#  'OPENDOORS',
#  'GRASSHOPPERSCAVALLETTE',
#  'SENZENINAWHATHAVEWEDONE',
#  'THERESTLESSCONSCIENCE',
#  'BIRDNESTERSOFTHAILANDAKASHADOWHUNTERS',
#  'CHILDRENOFNATURE',
#  'THEELEMENTARYSCHOOL',
#  'RAISETHEREDLANTERN',
#  'CLOSETOEDEN',
#  'APLACEINTHEWORLD',
#  'RECIRECIRECIWORDSWORDSWORDS',
#  'ALIEN3',
#  'FAREWELLMYCONCUBINE',
#  'CHILDRENOFFATE',
#  'BELLEEPOQUE',
#  'THESCENTOFGREENPAPAYA',
#  'THEWEDDINGBANQUET',
#  'THEMIGHTYRIVER',
#  'BLACKRIDERSCHWARZFAHRER',
#  'THESCREWLAVIS',
#  'QUEENMARGOT',
#  '89MMODEUROPY89MMFROMEUROPE',
#  'EATDRINKMANWOMAN',
#  'FARINELLIILCASTRATO',
#  'STRAWBERRYANDCHOCOLATE',
#  'THEMONKANDTHEFISH',
#  '12MONKEYS',
#  'SHANGHAITRIAD',
#  'FIDDLEFESTROBERTATZAVARASANDHEREASTHARLEMVIOLINPROGRAM',
#  'ALLTHINGSFAIR',
#  'ANTONIASLINE',
#  'MYFAMILYMIFAMILIA',
#  'THEPOSTMANILPOSTINO',
#  'GAGARIN',
#  'WILLIAMSHAKESPEARESROMEOJULIET',
#  'ACHEFINLOVE',
#  'KOLYA',
#  'THEOTHERSIDEOFSUNDAY',
#  'PRISONEROFTHEMOUNTAINS',
#  'DETRIPASCORAZON',
#  'ERNSTLYSET',
#  'FOURDAYSINSEPTEMBER',
#  'SECRETSOFTHEHEART',
#  'LAVIEILLEDAMEETLESPIGEONSTHEOLDLADYANDTHEPIGEONS',
#  'CENTRALSTATION',
#  'CHILDRENOFHEAVEN',
#  'THEGRANDFATHER',
#  'THECANTERBURYTALES',
#  'WHENLIFEDEPARTS',
#  'ELECTIONNIGHTVALGAFTEN',
#  'LACARTEPOSTALETHEPOSTCARD',
#  'ALLABOUTMYMOTHER',
#  'EASTWEST',
#  'THEREDVIOLIN',
#  'MYGRANDMOTHERIRONEDTHEKINGSSHIRTS',
#  'BRORMINBRORTEISANDNICO',
#  'KLEINGELDSMALLCHANGE',
#  'MAJORANDMINORMIRACLES',
#  'CROUCHINGTIGERHIDDENDRAGON',
#  'EVERYBODYFAMOUS',
#  'THETASTEOFOTHERS',
#  'DRSEUSSHOWTHEGRINCHSTOLECHRISTMAS',
#  'THEPERIWIGMAKER',
#  'QUIEROSERIWANTTOBE',
#  'ASOCCERSTORYUMAHISTORIADEFUTEBOL',
#  'HARRYPOTTERANDTHESORCERERSSTONE',
#  'MURDERONASUNDAYMORNING',
#  'LAGAAN',
#  'SONOFTHEBRIDE',
#  'GREGORSGREATESTINVENTION',
#  'AMANTHINGMESKASPRAWA',
#  'SPIRITEDAWAY',
#  'WINGEDMIGRATION',
#  'THEMANWITHOUTAPAST',
#  'NOWHEREINAFRICA',
#  'MTHEAD',
#  'ILLWAITFORTHENEXTONEJATTENDRAILESUIVANT',
#  'INJADOG',
#  'THISCHARMINGMANDERERENYNDIGMAND',
#  'TALKTOHER',
#  'THETRIPLETSOFBELLEVILLE',
#  'CITYOFGOD',
#  'MYARCHITECT',
#  'THEBARBARIANINVASIONS',
#  'THETWILIGHTSAMURAI',
#  'ZELARY',
#  'DIEROTEJACKETHEREDJACKET',
#  'MOSTTHEBRIDGE',
#  'ATORZIJAATORSION',
#  'MARIAFULLOFGRACE',
#  'AVERYLONGENGAGEMENT',
#  'HOUSEOFFLYINGDAGGERS',
#  'BORNINTOBROTHELS',
#  'THESTORYOFTHEWEEPINGCAMEL',
#  'THECHILDRENOFLENINGRADSKY',
#  'THECHORUSLESCHORISTES',
#  'THESEAINSIDE',
#  'THEMOTORCYCLEDIARIES',
#  '735INTHEMORNING735DELAMAANA',
#  'HOWLSMOVINGCASTLE',
#  'TIMBURTONSCORPSEBRIDE',
#  'WALLACEGROMITINTHECURSEOFTHEWERERABBIT',
#  'MARCHOFTHEPENGUINS',
#  'SOPHIESCHOLLTHEFINALDAYS',
#  'AUSREISSERTHERUNAWAY',
#  'THELASTFARM',
#  'PANSLABYRINTH',
#  'CURSEOFTHEGOLDENFLOWER',
#  'DAYSOFGLORYINDIGNES',
#  'THELIVESOFOTHERS',
#  'THEDANISHPOET',
#  'BINTAANDTHEGREATIDEABINTAYLAGRANIDEA',
#  'RAMOSPOCOSONETOOMANY',
#  'HELMERSON',
#  'THEDIVINGBELLANDTHEBUTTERFLY',
#  'LACORONATHECROWN',
#  'BEAUFORT',
#  'MONGOL',
#  'MMELESPIGEONSVONTAUPARADISEVENPIGEONSGOTOHEAVEN',
#  'MYLOVEMOYALYUBOV',
#  'ATNIGHT',
#  'ILSUPPLENTETHESUBSTITUTE',
#  'LEMOZARTDESPICKPOCKETSTHEMOZARTOFPICKPOCKETS',
#  'THEBAADERMEINHOFCOMPLEX',
#  'WALTZWITHBASHIR',
#  'LAMAISONENPETITSCUBES',
#  'LAVATORYLOVESTORY',
#  'AUFDERSTRECKEONTHELINE',
#  'MANONONTHEASPHALT',
#  'SPIELZEUGLANDTOYLAND',
#  'PRECIOUSBASEDONTHENOVELPUSHBYSAPPHIRE',
#  'THEWHITERIBBON',
#  'COCOBEFORECHANEL',
#  'BURMAVJ',
#  'RABBITLABERLIN',
#  'THEMILKOFSORROW',
#  'APROPHET',
#  'THESECRETINTHEIREYES',
#  'PARIS36',
#  'THELADYANDTHEREAPERLADAMAYLAMUERTE',
#  'INSTEADOFABRACADABRA',
#  'DOGTOOTH',
#  'INABETTERWORLD',
#  'OUTSIDETHELAWHORSLALOI',
#  'MADAGASCARCARNETDEVOYAGEMADAGASCARAJOURNEYDIARY',
#  'ACATINPARIS',
#  'BULLHEAD',
#  'DIMANCHESUNDAY',
#  'THEPIRATESBANDOFMISFITS',
#  '5BROKENCAMERAS',
#  'AROYALAFFAIR',
#  'WARWITCH',
#  'DEATHOFASHADOWDOODVANEENSCHADUW',
#  'MARVELSTHEAVENGERS',
#  'ERNESTCELESTINE',
#  'THEWINDRISES',
#  'THEGRANDMASTER',
#  'THEACTOFKILLING',
#  'KARAMAHASNOWALLS',
#  'THEGREATBEAUTY',
#  'THEMISSINGPICTURE',
#  'AQUELNOERAYOTHATWASNTME',
#  'AVANTQUEDETOUTPERDREJUSTBEFORELOSINGEVERYTHING',
#  'PITKMUNKAIKKIHOITAADOIHAVETOTAKECAREOFEVERYTHING',
#  'TWODAYSONENIGHT',
#  'THETALEOFTHEPRINCESSKAGUYA',
#  'THESALTOFTHEEARTH',
#  'OURCURSE',
#  'THEREAPERLAPARKA',
#  'TANGERINES',
#  'WILDTALES',
#  'MEANDMYMOULTON',
#  'BUTTERLAMPLALAMPEAUBEURREDEYAK',
#  'BOYANDTHEWORLD',
#  'WHENMARNIEWASTHERE',
#  'EMBRACEOFTHESERPENT',
#  'SONOFSAUL',
#  'AWAR',
#  'BEARSTORY',
#  'WECANTLIVEWITHOUTCOSMOS',
#  'EVERYTHINGWILLBEOKAYALLESWIRDGUT',
#  'MYLIFEASAZUCCHINI',
#  'THEREDTURTLE',
#  'FIREATSEA',
#  'WATANIMYHOMELAND',
#  'LANDOFMINE',
#  'AMANCALLEDOVE',
#  'BLINDVAYSHA',
#  'FACESPLACES',
#  'LASTMENINALEPPO',
#  'AFANTASTICWOMAN',
#  'THEINSULT',
#  'ONBODYANDSOUL',
#  'WATUWOTEALLOFUS',
#  'MIRAI',
#  'NEVERLOOKAWAY',
#  'CAPERNAUM',
#  'SHOPLIFTERS',
#  'PAINANDGLORY',
#  'ILOSTMYBODY',
#  'THEEDGEOFDEMOCRACY',
#  'INTHEABSENCE',
#  'DCERADAUGHTER',
#  'MEMORABLE',
#  'ASISTER',
#  'BORATSUBSEQUENTMOVIEFILMDELIVERYOFPRODIGIOUSBRIBETOAMERICANREGIMEFORMAKEBENEFITONCEGLORIOUSNATIONOFKAZAKHSTAN',
#  'COLLECTIVE',
#  'CRIPCAMP',
#  'THEMOLEAGENT',
#  'THEMANWHOSOLDHISSKIN',
#  'THELIFEAHEADLAVITADAVANTIASE',
#  'YESPEOPLE',
#  'WHITEEYE',
#  'PARALLELMOTHERS',
#  'THREESONGSFORBENAZIR',
#  'DRIVEMYCAR',
#  'THEHANDOFGOD',
#  'LUNANAAYAKINTHECLASSROOM',
#  'THEWORSTPERSONINTHEWORLD',
#  'BOXBALLET',
#  'ALAKACHUUTAKEANDRUN',
#  'BARDOFALSECHRONICLEOFAHANDFULOFTRUTHS',
#  'AHOUSEMADEOFSPLINTERS',
#  'HAULOUT',
#  'EO',
#  'THEQUIETGIRL',
#  'THEREDSUITCASE']

# %%
original_nominated_cleaned
# Out:
#       year_film                               film  winner
# 0          1927                          The Noose   False
# 1          1927                   The Last Command    True
# 2          1927                    A Ship Comes In   False
# 3          1927                         7th Heaven    True
# 4          1927                     Sadie Thompson   False
# ...         ...                                ...     ...
# 5093       2022                  Top Gun: Maverick    True
# 5094       2022           Avatar: The Way of Water    True
# 5095       2022  Glass Onion: A Knives Out Mystery   False
# 5096       2022                      Women Talking    True
# 5097       2022                Welcome to Chechnya    True
#
# [5098 rows x 3 columns]

# %%
# Create new list of not found that includes year from the original_nominated_cleaned dataframe
original_notFoundMovies_df = pd.DataFrame(columns=original_nominated_cleaned.columns)

# Iterate through notFoundMovies
for i in range(len(notFoundMovies)):
    # Filter rows from original_nominated_cleaned where the simplified name matches notFoundMovies[i]
    filtered_df = original_nominated_cleaned[original_nominated_cleaned['film'].str.upper().str.replace(r'[^A-Z0-9]', '') == notFoundMovies[i]]

    if not filtered_df.empty:
        original_notFoundMovies_df = original_notFoundMovies_df.append(filtered_df, ignore_index=True)
# Out:
# /var/folders/pv/4s9_lh1909z14tnpgcdzkk3m0000gn/T/ipykernel_2354/815566772.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   filtered_df = original_nominated_cleaned[original_nominated_cleaned['film'].str.upper().str.replace(r'[^A-Z0-9]', '') == notFoundMovies[i]]
# /var/folders/pv/4s9_lh1909z14tnpgcdzkk3m0000gn/T/ipykernel_2354/815566772.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   original_notFoundMovies_df = original_notFoundMovies_df.append(filtered_df, ignore_index=True)

# %%
original_notFoundMovies_df
# how many winners in the not found movies
original_notFoundMovies_df['winner'].value_counts()
# Out:
# False    437
# True     106
# Name: winner, dtype: int64

# %%
movie_title = ""
movie_year = ""
notFoundMovies = []
from urllib.parse import quote
# Extract movie ID from TheMovieDB API by appending to original movie_ids list
for i in tqdm(range(len(original_notFoundMovies_df))):
    # Get the movie id from the simple_extract dataframe
    movie_title = original_notFoundMovies_df['film'][i]
    title_encoded = quote(movie_title)
    movie_year = original_notFoundMovies_df['year_film'][i]

    resp = r.get(f'https://api.themoviedb.org/3/search/movie?api_key={API_KEY}&language=en-US&query={title_encoded}&page=1&include_adult=false&year={movie_year}')
    try:
        movie_id = resp.json()['results'][0]['id']
    except IndexError:
        try:
            movie_year += 1
            resp = r.get(f'https://api.themoviedb.org/3/search/movie?api_key={API_KEY}&language=en-US&query={title_encoded}&page=1&include_adult=false&year={movie_year}')
            movie_id = resp.json()['results'][0]['id']
        except IndexError:
            try:
                movie_year -= 2
                resp = r.get(f'https://api.themoviedb.org/3/search/movie?api_key={API_KEY}&language=en-US&query={title_encoded}&page=1&include_adult=false&year={movie_year}')
                movie_id = resp.json()['results'][0]['id']
            except IndexError:
                try:
                    resp = r.get(f'https://api.themoviedb.org/3/search/movie?api_key={API_KEY}&language=en-US&query={title_encoded}&page=1&include_adult=false')
                    movie_id = resp.json()['results'][0]['id']
                except IndexError:
                    movie_id = movie_title
    #movie_ids.append(movie_id)
    if movie_id != movie_title:
        movie_ids.append(movie_id)
    else:
        notFoundMovies.append(movie_title)
# Out:
# 100%|██████████| 543/543 [01:03<00:00,  8.56it/s]

# %% [markdown]
# ### Printing out number of nominated/winners that were not found on database

# %%
# Check how many not found
print(len(notFoundMovies))
notFoundMovies
# Out:
# 22
# ["Walter Wanger's Vogues of 1938",
#  'One Hundred Men and a Girl',
#  'Mr. Gardenia Jones',
#  'Paramount News Issue #37 (Twentieth Anniversary Issue!  1927.....1947)',
#  "Chopin's Musical Moments",
#  'The Strauss Fantasy',
#  'The Running, Jumping and Standing-Still Film',
#  'Song without End (The Story of Franz Liszt)',
#  'La Grande Olimpiade (Olympic Games 1960)',
#  "Meredith Willson's The Music Man",
#  "The Cliff Dwellers (formerly titled 'One Plus One')",
#  "Jacques-Yves Cousteau's World without Sun",
#  'A Year toward Tomorrow',
#  'Herb Alpert and the Tijuana Brass Double Feature',
#  'The Legendary Champions',
#  'The Further Adventures of Uncle Sam: Part Two',
#  'The Doonesbury Special',
#  'Mama Turns a Hundred',
#  'The Yellow Star - The Persecution of the Jews in Europe 1933-45',
#  "Eyes on the Prize: America's Civil Rights Years/Bridge to Freedom 1965",
#  'Senzeni Na? (What Have We Done?)',
#  "Birdnesters of Thailand (aka 'Shadow Hunters')"]

# %% [markdown]
# ## Extracting the rest of the data

# %%
print(len(movie_ids))
# Out:
# 5656

# %%
#Method for getting stats

def compute_top_seven_avg(df, col):
    try:
        top = df[col].sort_values(ascending=False)
        top = top[:min(len(df), 7)]
        return top.sum() / len(top)
    except:
        return np.nan
    
def get_popularity_stats(resp, col):
    result = {}

    try:
        data = pd.DataFrame(resp.json()[col])
        
        try:
            result['avg'] = compute_top_seven_avg(data, 'popularity')
        except:
            result['avg'] = np.nan

        try:
            result['sum'] = data['popularity'].sum()
        except:
            result['sum'] = np.nan

        try:
            result['top'] = data['popularity'].max()
        except:
            result['top'] = np.nan

    except KeyError:
        result['avg'] = np.nan
        result['sum'] = np.nan
        result['top'] = np.nan
        
    return result

# %%
#movie ID gets stats of movie
#credit get 

#Get Movie Stats through MovieID
rows = []

col = ['id', 'title', 'budget', 'revenue', 'release_date', 'popularity', 'vote_average', 'runtime', 'top_casts_popularity_avg', 'casts_popularity_sum', 'top_cast_popularity',
       'top_crews_popularity_avg', 'crews_popularity_sum', 'top_crew_popularity']
for i in tqdm(range(len(movie_ids))):
    row = []
    j = movie_ids[i]
    resp = r.get(f'https://api.themoviedb.org/3/movie/{j}?api_key={API_KEY}')
    try:
        budget = resp.json()['id']
        if budget == 0:
            row.append(np.nan)
        else:
            row.append(budget)
    except KeyError:
        row.append(np.nan)
    try:
        budget = resp.json()['title']
        if budget == 0:
            row.append(np.nan)
        else:
            row.append(budget)
    except KeyError:
        row.append(np.nan)
    try:
        budget = resp.json()['budget']
        if budget == 0:
            row.append(np.nan)
        else:
            row.append(budget)
    except KeyError:
        row.append(np.nan)
    try:
        revenue = resp.json()['revenue']
        if revenue == 0:
            row.append(np.nan)
        else:
            row.append(revenue)
    except KeyError:
        row.append(np.nan)
    try:
        release = resp.json()['release_date'][0:4]
        row.append(release)
    except:
        row.append(np.nan)
    try:
        remaining = resp.json()['popularity']
        if(remaining == 0):
            row.append(np.nan)
        else:
            row.append(remaining)
    except:
        row.append(np.nan)

    try:
        voteA = resp.json()['vote_average']
        if(voteA == 0):
            row.append(np.nan)
        else:
            row.append(voteA)
    except:
        row.append(np.nan)

    try:
        runtime = resp.json()['runtime']
        if(runtime == 0):
            row.append(np.nan)
        else:
            row.append(runtime)
    except:
        row.append(np.nan)

    #credits part
    resp = r.get(f'https://api.themoviedb.org/3/movie/{j}/credits?api_key={API_KEY}&language=en-US')
    casts_stats = get_popularity_stats(resp, 'cast')

    row.append(casts_stats['avg'])
    row.append(casts_stats['sum'])
    row.append(casts_stats['top'])
        
    # Get crews' popularity statistics from the movie
    crews_stats = get_popularity_stats(resp, 'crew')
        
    # Append to row
    row.append(crews_stats['avg'])
    row.append(crews_stats['sum'])
    row.append(crews_stats['top'])

    rows.append(row)

property = pd.DataFrame(rows, columns = col)

#combine = pd.concat([movie_data, property], axis=1)


print(property.head(5))
# Out:
# 100%|██████████| 5656/5656 [1:00:37<00:00,  1.55it/s]
#          id             title     budget    revenue release_date  popularity  \
# 0  113167.0         The Noose        NaN        NaN         1928       0.600
# 1   43197.0  The Last Command        NaN        NaN         1955       2.108
# 2  104212.0   A Ship Comes In        NaN        NaN         1928       0.790
# 3   82474.0        7th Heaven      119.0        NaN         1927       5.695
# 4   42538.0    Sadie Thompson  1000000.0  7000000.0         1928       1.643
#
#    vote_average  runtime  top_casts_popularity_avg  casts_popularity_sum  \
# 0           NaN     65.0                  1.582286                15.598
# 1          6.40    110.0                 11.207714               109.128
# 2          5.50     70.0                  1.531000                11.317
# 3          7.37    110.0                  2.758571                25.023
# 4          6.80     97.0                  2.442286                18.896
#
#    top_cast_popularity  top_crews_popularity_avg  crews_popularity_sum  \
# 0                2.260                  0.722000                 5.654
# 1               21.641                  1.352143                15.417
# 2                4.116                  1.016571                 7.716
# 3                8.574                  1.284000                20.293
# 4                6.750                  1.789000                13.723
#
#    top_crew_popularity
# 0                0.980
# 1                2.167
# 2                1.380
# 3                2.268
# 4                2.301

# %%
property.to_csv('datasets/oscar_nom_extract.csv', index=False)

# %%
original_nominated_cleaned.to_csv('Nominated/winner_nom.csv')
