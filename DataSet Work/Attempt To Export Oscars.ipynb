# %%
# For data processing
import numpy as np
import pandas as pd

# For API usage
import requests as r

# For progress bar
from tqdm import tqdm

# %%
oscarData = pd.read_csv('the_oscar_award.csv')
oscarData.head()
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False

# %%
print("Data type : ", type(oscarData))
print("Data dims : ", oscarData.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (10765, 7)

# %%
print(oscarData.dtypes)
# Out:
# year_film         int64
# year_ceremony     int64
# ceremony          int64
# category         object
# name             object
# film             object
# winner             bool
# dtype: object

# %%
bestPic = oscarData[['year_film','category','film','winner']]

# %%
bestPic2 = oscarData[(oscarData['category'].isin(['BEST PICTURE'])) & (oscarData['winner'].isin(['TRUE']))]
print (bestPic2)
# Out:
# Empty DataFrame
# Columns: [year_film, year_ceremony, ceremony, category, name, film, winner]
# Index: []

# %%
winners = oscarData[oscarData['winner']]

# %%
bestPic2 = winners[(winners['category'] == "BEST PICTURE") | (winners['category'] == "OUTSTANDING PICTURE") | (winners['category'] == "OUTSTANDING PRODUCTION") | (winners['category'] == "OUTSTANDING MOTION PICTURE") | (winners['category'] == "BEST MOTION PICTURE")]

# %%
bestPic2
# Out:
#        year_film  year_ceremony  ceremony                category  \
# 21          1927           1928         1     OUTSTANDING PICTURE
# 64          1928           1929         2     OUTSTANDING PICTURE
# 100         1929           1930         3  OUTSTANDING PRODUCTION
# 140         1930           1931         4  OUTSTANDING PRODUCTION
# 178         1931           1932         5  OUTSTANDING PRODUCTION
# ...          ...            ...       ...                     ...
# 10219       2018           2019        91            BEST PICTURE
# 10350       2019           2020        92            BEST PICTURE
# 10474       2020           2021        93            BEST PICTURE
# 10591       2021           2022        94            BEST PICTURE
# 10718       2022           2023        95            BEST PICTURE
#
#                                                     name  \
# 21                                Paramount Famous Lasky
# ...

# %%
bestPic2 = bestPic2.reset_index(drop=True)

# %%
# Out:
#     year_film  year_ceremony  ceremony                category  \
# 0        1927           1928         1     OUTSTANDING PICTURE
# 1        1928           1929         2     OUTSTANDING PICTURE
# 2        1929           1930         3  OUTSTANDING PRODUCTION
# 3        1930           1931         4  OUTSTANDING PRODUCTION
# 4        1931           1932         5  OUTSTANDING PRODUCTION
# ..        ...            ...       ...                     ...
# 90       2018           2019        91            BEST PICTURE
# 91       2019           2020        92            BEST PICTURE
# 92       2020           2021        93            BEST PICTURE
# 93       2021           2022        94            BEST PICTURE
# 94       2022           2023        95            BEST PICTURE
#
#                                                  name  \
# 0                              Paramount Famous Lasky
# 1                                 Metro-Goldwyn-Mayer
# ...

# %%
bestPic2.to_csv('BestPicWinners.csv', index = True)
